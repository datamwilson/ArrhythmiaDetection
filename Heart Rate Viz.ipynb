# %%
import pandas as pd
from matplotlib import pyplot

# %%
heartData = pd.read_csv('/HeartRate.csv')

# %%
heartData[['type', 'creationDate', 'value']]
# Out:
#             type               creationDate  value
# 0      HeartRate  2016-09-12 19:14:34 -0500     88
# 1      HeartRate  2016-09-12 19:19:50 -0500     88
# 2      HeartRate  2016-09-12 19:24:28 -0500     89
# 3      HeartRate  2016-09-12 19:32:16 -0500     84
# 4      HeartRate  2016-09-12 19:34:38 -0500     88
# 5      HeartRate  2016-09-12 19:39:29 -0500     88
# 6      HeartRate  2016-09-12 19:42:12 -0500     87
# 7      HeartRate  2016-09-12 19:42:17 -0500     88
# 8      HeartRate  2016-09-12 19:49:00 -0500     88
# 9      HeartRate  2016-09-12 19:54:39 -0500     89
# 10     HeartRate  2016-09-12 19:57:43 -0500     88
# 11     HeartRate  2016-09-12 20:03:07 -0500     94
# 12     HeartRate  2016-09-12 20:12:15 -0500     88
# 13     HeartRate  2016-09-13 06:06:20 -0500     97
# 14     HeartRate  2016-09-13 06:11:33 -0500     97
# 15     HeartRate  2016-09-13 06:22:56 -0500     89
# 16     HeartRate  2016-09-13 06:32:58 -0500     93
# ...

# %%
heartData.plot(x='creationDate', y='value')
